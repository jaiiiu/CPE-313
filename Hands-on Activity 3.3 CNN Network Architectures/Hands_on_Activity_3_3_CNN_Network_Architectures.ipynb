# %% [markdown]
# # Activity 3.3 - CNN Network Architectures

# %% [markdown]
# #### Objective(s):
#
# This activity aims to introduce how to use CNN network architectures

# %% [markdown]
# #### Intended Learning Outcomes (ILOs):
# * Demonstrate how to use pretrained model in predicting the object
# * Evaluate the accuracy of each pretrained model

# %% [markdown]
# #### Resources:
# * Jupyter Notebook
# * MNIST

# %% [markdown]
# #### Procedures
# Load the necessary libraries

# %%
# install opencv if you haven't
# pip install opencv-python
# pip install pillow

# %%
from PIL import Image
from keras.preprocessing import image
import numpy as np
import pandas as pd

import cv2

from matplotlib.image import imread
import matplotlib.pyplot as plt

# %% [markdown]
# Create a function that will capture and save the image from your webcam

# %%
# def get_image(camera):
#     retval, im = camera.read()
#     return im

# %%
# def save_webcam_image(img_path):

#     try:
#         camera_port = 0
#         ramp_frames = 10

#         camera = cv2.VideoCapture(camera_port)

#         for i in range(ramp_frames):
#             retval, im_camera = camera.read()

#         retval, im_camera = camera.read()

#         im = cv2.resize(im_camera, (224, 224)).astype(np.float32)
#         cv2.imwrite(img_path, im)
#         del (camera)
#         return True
#     except ValueError as e:
#         print("Image Capture Failed")
#     return False

# %% [markdown]
# Using the Google Colab code snippet for camera capture

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => capture.onclick = resolve);

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %%
from IPython.display import Image

try:
    filename = take_photo()
    print('Saved to {}'.format(filename))

    # Load the captured image
    img = cv2.imread(filename)

    # Resize the image to 224x224
    resized_img = cv2.resize(img, (224, 224))

    # Save the resized image
    resized_filename = 'resized_photo.jpg'
    cv2.imwrite(resized_filename, resized_img)

    print('Resized image saved to {}'.format(resized_filename))

except Exception as err:
    # Errors will be thrown if the user does not have a webcam or if they do not
    # grant the page permission to access it.
    print(str(err))
# Out:
# Saved to photo.jpg
# Resized image saved to resized_photo.jpg

# %% [markdown]
# * Test your function.
# * Place a clock or any object
# * Display the saved image

# %%
img_path = "/content/resized_photo.jpg"

# if save_webcam_image(img_path) is False:
#     # Webcam not active, use the Dog Image
#     img_path = "rocking_chair.jpg"
#     print("Using the Test Rocking Chair Image: {}".format(img_path))

# %%
plt.imshow(imread(img_path))

# %% [markdown]
# Use VGG-16 pre-trained model

# %%
from keras.applications import vgg16

vgg16_model = vgg16.VGG16(weights='imagenet')
vgg16_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Create a function to load model, image, preprocess input and targets

# %%
def predict_image(model, img_path, preprocess_input_fn, decode_predictions_fn, target_size=(224, 224)):

    img = image.load_img(img_path, target_size=target_size)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input_fn(x)

    preds = model.predict(x)
    predictions_df = pd.DataFrame(decode_predictions_fn(preds, top=10)[0])
    predictions_df.columns = ["Predicted Class", "Name", "Probability"]
    return predictions_df

# %% [markdown]
# Predict the result

# %%
predict_image(vgg16_model, img_path, vgg16.preprocess_input, vgg16.decode_predictions)
# Out:
# 1/1 [==============================] - 1s 779ms/step
#   Predicted Class        Name  Probability
# 0       n04423845     thimble     0.466310
# 1       n03759954  microphone     0.280930
# 2       n03916031     perfume     0.037975
# 3       n03666591     lighter     0.027804
# 4       n04372370      switch     0.025579
# 5       n04579432     whistle     0.012929
# 6       n02910353      buckle     0.011715
# 7       n04286575   spotlight     0.009757
# 8       n03424325     gasmask     0.007375
# 9       n04141327    scabbard     0.006883

# %% [markdown]
# Interpret the result of prediction using VGG16 model

# %% [markdown]
# > The model incorrectly predicted the object in the picture. I can definitely see how the model got confused, the grill/top of the microphone can be mistaken as a thimble, especially when the picture provided has low quality. Some more uncommon features of the microphone, specifically the white box, may have confused the model. The color can also be a factor.

# %% [markdown]
# Use Resnet50 pretrained model

# %%
from keras.applications import resnet50

resnet50_model = resnet50.ResNet50(weights='imagenet')

resnet50_model.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_2[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block1_2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block1_2_bn[0][0]']
#  ation)
#
#  conv2_block1_0_conv (Conv2  (None, 56, 56, 256)          16640     ['pool1_pool[0][0]']
#  D)
#
#  conv2_block1_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block1_2_relu[0][0]']
#  D)
#
#  conv2_block1_0_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_0_conv[0][0]']
#  rmalization)
#
#  conv2_block1_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block1_3_conv[0][0]']
#  rmalization)
#
#  conv2_block1_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_0_bn[0][0]',
#                                                                      'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activati  (None, 56, 56, 256)          0         ['conv2_block1_add[0][0]']
#  on)
#
#  conv2_block2_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block1_out[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block2_2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block2_2_bn[0][0]']
#  ation)
#
#  conv2_block2_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block2_2_relu[0][0]']
#  D)
#
#  conv2_block2_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block2_3_conv[0][0]']
#  rmalization)
#
#  conv2_block2_add (Add)      (None, 56, 56, 256)          0         ['conv2_block1_out[0][0]',
#                                                                      'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activati  (None, 56, 56, 256)          0         ['conv2_block2_add[0][0]']
#  on)
#
#  conv2_block3_1_conv (Conv2  (None, 56, 56, 64)           16448     ['conv2_block2_out[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 56, 56, 64)           36928     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_2_bn (BatchNo  (None, 56, 56, 64)           256       ['conv2_block3_2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_2_relu (Activ  (None, 56, 56, 64)           0         ['conv2_block3_2_bn[0][0]']
#  ation)
#
#  conv2_block3_3_conv (Conv2  (None, 56, 56, 256)          16640     ['conv2_block3_2_relu[0][0]']
#  D)
#
#  conv2_block3_3_bn (BatchNo  (None, 56, 56, 256)          1024      ['conv2_block3_3_conv[0][0]']
#  rmalization)
#
#  conv2_block3_add (Add)      (None, 56, 56, 256)          0         ['conv2_block2_out[0][0]',
#                                                                      'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activati  (None, 56, 56, 256)          0         ['conv2_block3_add[0][0]']
#  on)
#
#  conv3_block1_1_conv (Conv2  (None, 28, 28, 128)          32896     ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block1_2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block1_2_bn[0][0]']
#  ation)
#
#  conv3_block1_0_conv (Conv2  (None, 28, 28, 512)          131584    ['conv2_block3_out[0][0]']
#  D)
#
#  conv3_block1_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block1_2_relu[0][0]']
#  D)
#
#  conv3_block1_0_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_0_conv[0][0]']
#  rmalization)
#
#  conv3_block1_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block1_3_conv[0][0]']
#  rmalization)
#
#  conv3_block1_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_0_bn[0][0]',
#                                                                      'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activati  (None, 28, 28, 512)          0         ['conv3_block1_add[0][0]']
#  on)
#
#  conv3_block2_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block1_out[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block2_2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block2_2_bn[0][0]']
#  ation)
#
#  conv3_block2_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block2_2_relu[0][0]']
#  D)
#
#  conv3_block2_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block2_3_conv[0][0]']
#  rmalization)
#
#  conv3_block2_add (Add)      (None, 28, 28, 512)          0         ['conv3_block1_out[0][0]',
#                                                                      'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activati  (None, 28, 28, 512)          0         ['conv3_block2_add[0][0]']
#  on)
#
#  conv3_block3_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block2_out[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block3_2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block3_2_bn[0][0]']
#  ation)
#
#  conv3_block3_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block3_2_relu[0][0]']
#  D)
#
#  conv3_block3_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block3_3_conv[0][0]']
#  rmalization)
#
#  conv3_block3_add (Add)      (None, 28, 28, 512)          0         ['conv3_block2_out[0][0]',
#                                                                      'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activati  (None, 28, 28, 512)          0         ['conv3_block3_add[0][0]']
#  on)
#
#  conv3_block4_1_conv (Conv2  (None, 28, 28, 128)          65664     ['conv3_block3_out[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 28, 28, 128)          147584    ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_2_bn (BatchNo  (None, 28, 28, 128)          512       ['conv3_block4_2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_2_relu (Activ  (None, 28, 28, 128)          0         ['conv3_block4_2_bn[0][0]']
#  ation)
#
#  conv3_block4_3_conv (Conv2  (None, 28, 28, 512)          66048     ['conv3_block4_2_relu[0][0]']
#  D)
#
#  conv3_block4_3_bn (BatchNo  (None, 28, 28, 512)          2048      ['conv3_block4_3_conv[0][0]']
#  rmalization)
#
#  conv3_block4_add (Add)      (None, 28, 28, 512)          0         ['conv3_block3_out[0][0]',
#                                                                      'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activati  (None, 28, 28, 512)          0         ['conv3_block4_add[0][0]']
#  on)
#
#  conv4_block1_1_conv (Conv2  (None, 14, 14, 256)          131328    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block1_2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block1_2_bn[0][0]']
#  ation)
#
#  conv4_block1_0_conv (Conv2  (None, 14, 14, 1024)         525312    ['conv3_block4_out[0][0]']
#  D)
#
#  conv4_block1_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block1_2_relu[0][0]']
#  D)
#
#  conv4_block1_0_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_0_conv[0][0]']
#  rmalization)
#
#  conv4_block1_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block1_3_conv[0][0]']
#  rmalization)
#
#  conv4_block1_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_0_bn[0][0]',
#                                                                      'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block1_add[0][0]']
#  on)
#
#  conv4_block2_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block1_out[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block2_2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block2_2_bn[0][0]']
#  ation)
#
#  conv4_block2_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block2_2_relu[0][0]']
#  D)
#
#  conv4_block2_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block2_3_conv[0][0]']
#  rmalization)
#
#  conv4_block2_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block1_out[0][0]',
#                                                                      'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block2_add[0][0]']
#  on)
#
#  conv4_block3_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block2_out[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block3_2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block3_2_bn[0][0]']
#  ation)
#
#  conv4_block3_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block3_2_relu[0][0]']
#  D)
#
#  conv4_block3_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block3_3_conv[0][0]']
#  rmalization)
#
#  conv4_block3_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block2_out[0][0]',
#                                                                      'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block3_add[0][0]']
#  on)
#
#  conv4_block4_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block3_out[0][0]']
#  D)
#
#  conv4_block4_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_1_bn[0][0]']
#  ation)
#
#  conv4_block4_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block4_1_relu[0][0]']
#  D)
#
#  conv4_block4_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block4_2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block4_2_bn[0][0]']
#  ation)
#
#  conv4_block4_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block4_2_relu[0][0]']
#  D)
#
#  conv4_block4_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block4_3_conv[0][0]']
#  rmalization)
#
#  conv4_block4_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block3_out[0][0]',
#                                                                      'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block4_add[0][0]']
#  on)
#
#  conv4_block5_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block4_out[0][0]']
#  D)
#
#  conv4_block5_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_1_bn[0][0]']
#  ation)
#
#  conv4_block5_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block5_1_relu[0][0]']
#  D)
#
#  conv4_block5_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block5_2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block5_2_bn[0][0]']
#  ation)
#
#  conv4_block5_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block5_2_relu[0][0]']
#  D)
#
#  conv4_block5_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block5_3_conv[0][0]']
#  rmalization)
#
#  conv4_block5_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block4_out[0][0]',
#                                                                      'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block5_add[0][0]']
#  on)
#
#  conv4_block6_1_conv (Conv2  (None, 14, 14, 256)          262400    ['conv4_block5_out[0][0]']
#  D)
#
#  conv4_block6_1_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_1_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_1_bn[0][0]']
#  ation)
#
#  conv4_block6_2_conv (Conv2  (None, 14, 14, 256)          590080    ['conv4_block6_1_relu[0][0]']
#  D)
#
#  conv4_block6_2_bn (BatchNo  (None, 14, 14, 256)          1024      ['conv4_block6_2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_2_relu (Activ  (None, 14, 14, 256)          0         ['conv4_block6_2_bn[0][0]']
#  ation)
#
#  conv4_block6_3_conv (Conv2  (None, 14, 14, 1024)         263168    ['conv4_block6_2_relu[0][0]']
#  D)
#
#  conv4_block6_3_bn (BatchNo  (None, 14, 14, 1024)         4096      ['conv4_block6_3_conv[0][0]']
#  rmalization)
#
#  conv4_block6_add (Add)      (None, 14, 14, 1024)         0         ['conv4_block5_out[0][0]',
#                                                                      'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activati  (None, 14, 14, 1024)         0         ['conv4_block6_add[0][0]']
#  on)
#
#  conv5_block1_1_conv (Conv2  (None, 7, 7, 512)            524800    ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_1_bn[0][0]']
#  ation)
#
#  conv5_block1_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block1_1_relu[0][0]']
#  D)
#
#  conv5_block1_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block1_2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block1_2_bn[0][0]']
#  ation)
#
#  conv5_block1_0_conv (Conv2  (None, 7, 7, 2048)           2099200   ['conv4_block6_out[0][0]']
#  D)
#
#  conv5_block1_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block1_2_relu[0][0]']
#  D)
#
#  conv5_block1_0_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_0_conv[0][0]']
#  rmalization)
#
#  conv5_block1_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block1_3_conv[0][0]']
#  rmalization)
#
#  conv5_block1_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_0_bn[0][0]',
#                                                                      'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block1_add[0][0]']
#  on)
#
#  conv5_block2_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block1_out[0][0]']
#  D)
#
#  conv5_block2_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_1_bn[0][0]']
#  ation)
#
#  conv5_block2_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block2_1_relu[0][0]']
#  D)
#
#  conv5_block2_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block2_2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block2_2_bn[0][0]']
#  ation)
#
#  conv5_block2_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block2_2_relu[0][0]']
#  D)
#
#  conv5_block2_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block2_3_conv[0][0]']
#  rmalization)
#
#  conv5_block2_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block1_out[0][0]',
#                                                                      'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block2_add[0][0]']
#  on)
#
#  conv5_block3_1_conv (Conv2  (None, 7, 7, 512)            1049088   ['conv5_block2_out[0][0]']
#  D)
#
#  conv5_block3_1_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_1_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_1_bn[0][0]']
#  ation)
#
#  conv5_block3_2_conv (Conv2  (None, 7, 7, 512)            2359808   ['conv5_block3_1_relu[0][0]']
#  D)
#
#  conv5_block3_2_bn (BatchNo  (None, 7, 7, 512)            2048      ['conv5_block3_2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_2_relu (Activ  (None, 7, 7, 512)            0         ['conv5_block3_2_bn[0][0]']
#  ation)
#
#  conv5_block3_3_conv (Conv2  (None, 7, 7, 2048)           1050624   ['conv5_block3_2_relu[0][0]']
#  D)
#
#  conv5_block3_3_bn (BatchNo  (None, 7, 7, 2048)           8192      ['conv5_block3_3_conv[0][0]']
#  rmalization)
#
#  conv5_block3_add (Add)      (None, 7, 7, 2048)           0         ['conv5_block2_out[0][0]',
#                                                                      'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activati  (None, 7, 7, 2048)           0         ['conv5_block3_add[0][0]']
#  on)
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['conv5_block3_out[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 25636712 (97.80 MB)
# Trainable params: 25583592 (97.59 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Predict the result

# %%
predict_image(resnet50_model, img_path, resnet50.preprocess_input, resnet50.decode_predictions)
# Out:
# 1/1 [==============================] - 3s 3s/step
#   Predicted Class              Name  Probability
# 0       n03759954        microphone     0.971691
# 1       n04423845           thimble     0.027603
# 2       n04141327          scabbard     0.000218
# 3       n03666591           lighter     0.000109
# 4       n04041544             radio     0.000088
# 5       n03483316       hand_blower     0.000041
# 6       n04286575         spotlight     0.000019
# 7       n03075370  combination_lock     0.000019
# 8       n04153751             screw     0.000014
# 9       n04154565       screwdriver     0.000013

# %% [markdown]
# Interpret the result using RESNET50 pretrained model

# %% [markdown]
# > The RESENET50 correctly predicted the right class for the object with a confident 97% probability. This shows that the input may not necessarily be the problem, but it is also unjust to put the blame on the model, since there are still other factors such as differences in hyperparameter settings during training that can impact the model's prediction capabilities.

# %% [markdown]
# #### Supplementary Activity

# %% [markdown]
# * Use at least three pretrained model and predict the result using the saved image.
# * Compare their accuracy results.

# %% [markdown]
# Using Xception

# %%
from keras.applications import xception

xception_model = xception.Xception(weights='imagenet')
xception_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels.h5
# 91884032/91884032 [==============================] - 1s 0us/step
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 149, 149, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 149, 149, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 149, 149, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 147, 147, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 147, 147, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 147, 147, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 147, 147, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 147, 147, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 147, 147, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 147, 147, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 74, 74, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 74, 74, 128)          512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 74, 74, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 74, 74, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 74, 74, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 74, 74, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 74, 74, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 74, 74, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 37, 37, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 37, 37, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 37, 37, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 37, 37, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 37, 37, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 37, 37, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 37, 37, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 37, 37, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 19, 19, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 19, 19, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 19, 19, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 19, 19, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 19, 19, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 19, 19, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 19, 19, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 19, 19, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 19, 19, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 19, 19, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 19, 19, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 19, 19, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 19, 19, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 19, 19, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 19, 19, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 19, 19, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 19, 19, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 19, 19, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 19, 19, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 19, 19, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 19, 19, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 19, 19, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 19, 19, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 19, 19, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 19, 19, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 1024)         745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 10, 10, 1024)         0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 10, 10, 1024)         4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 10, 10, 1024)         0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 10, 10, 1536)         1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 10, 10, 1536)         6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 10, 10, 1536)         0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 10, 10, 2048)         3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 10, 10, 2048)         8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 10, 10, 2048)         0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  avg_pool (GlobalAveragePoo  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 2049000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 22910480 (87.40 MB)
# Trainable params: 22855952 (87.19 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
predict_image(xception_model, img_path, xception.preprocess_input, xception.decode_predictions, (299, 299))
# Out:
# 1/1 [==============================] - 3s 3s/step
#   Predicted Class              Name  Probability
# 0       n03759954        microphone     0.919295
# 1       n04372370            switch     0.017499
# 2       n04141327          scabbard     0.014022
# 3       n04423845           thimble     0.009939
# 4       n04041544             radio     0.002406
# 5       n04456115             torch     0.002158
# 6       n03075370  combination_lock     0.001929
# 7       n03874599           padlock     0.001866
# 8       n03666591           lighter     0.001029
# 9       n03777754             modem     0.000971

# %% [markdown]
# Using InceptionResNetV2

# %%
from keras.applications import inception_resnet_v2

inception_resnet_model = inception_resnet_v2.InceptionResNetV2(weights='imagenet')
inception_resnet_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels.h5
# 225209952/225209952 [==============================] - 1s 0us/step
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 299, 299, 3)]        0         []
#
#  conv2d_4 (Conv2D)           (None, 149, 149, 32)         864       ['input_4[0][0]']
#
#  batch_normalization_4 (Bat  (None, 149, 149, 32)         96        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation (Activation)     (None, 149, 149, 32)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 147, 147, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_5 (Bat  (None, 147, 147, 32)         96        ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 147, 147, 32)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 147, 147, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_6 (Bat  (None, 147, 147, 64)         192       ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 147, 147, 64)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 73, 73, 64)           0         ['activation_2[0][0]']
#  D)
#
#  conv2d_7 (Conv2D)           (None, 73, 73, 80)           5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_7 (Bat  (None, 73, 73, 80)           240       ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 73, 73, 80)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv2d_8 (Conv2D)           (None, 71, 71, 192)          138240    ['activation_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 71, 71, 192)          576       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 71, 71, 192)          0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 35, 35, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 35, 35, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 35, 35, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_10 (Conv2D)          (None, 35, 35, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 35, 35, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 35, 35, 48)           144       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_13 (Ba  (None, 35, 35, 96)           288       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 35, 35, 48)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_9 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  average_pooling2d (Average  (None, 35, 35, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_9 (Conv2D)           (None, 35, 35, 96)           18432     ['max_pooling2d_1[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 35, 35, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 35, 35, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 35, 35, 64)           12288     ['average_pooling2d[0][0]']
#
#  batch_normalization_9 (Bat  (None, 35, 35, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 35, 35, 64)           192       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 35, 35, 96)           288       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 35, 35, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 35, 35, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 35, 35, 64)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  activation_10 (Activation)  (None, 35, 35, 96)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  mixed_5b (Concatenate)      (None, 35, 35, 320)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_19 (Ba  (None, 35, 35, 32)           96        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_15[0][0]']
#
#  batch_normalization_17 (Ba  (None, 35, 35, 32)           96        ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_20 (Ba  (None, 35, 35, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 35, 35, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_13[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_16[0][0]']
#
#  batch_normalization_16 (Ba  (None, 35, 35, 32)           96        ['conv2d_16[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 35, 35, 32)           96        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 35, 35, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  block35_1_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_12[0][0]',
#  te)                                                                 'activation_14[0][0]',
#                                                                      'activation_17[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer (Custom  (None, 35, 35, 320)          0         ['mixed_5b[0][0]',
#  ScaleLayer)                                                         'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_25 (Ba  (None, 35, 35, 32)           96        ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_21[0][0]']
#
#  batch_normalization_23 (Ba  (None, 35, 35, 32)           96        ['conv2d_23[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 35, 35, 48)           144       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  activation_22 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_19[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_22[0][0]']
#
#  batch_normalization_22 (Ba  (None, 35, 35, 32)           96        ['conv2d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 35, 35, 32)           96        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 35, 35, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  activation_20 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  block35_2_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_18[0][0]',
#  te)                                                                 'activation_20[0][0]',
#                                                                      'activation_23[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_1 (Cust  (None, 35, 35, 320)          0         ['block35_1_ac[0][0]',
#  omScaleLayer)                                                       'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_1[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_31 (Ba  (None, 35, 35, 32)           96        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_27[0][0]']
#
#  batch_normalization_29 (Ba  (None, 35, 35, 32)           96        ['conv2d_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_32 (Ba  (None, 35, 35, 48)           144       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  activation_28 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_25[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_28[0][0]']
#
#  batch_normalization_28 (Ba  (None, 35, 35, 32)           96        ['conv2d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 35, 35, 32)           96        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 35, 35, 64)           192       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  activation_26 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  block35_3_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_24[0][0]',
#  te)                                                                 'activation_26[0][0]',
#                                                                      'activation_29[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_2 (Cust  (None, 35, 35, 320)          0         ['block35_2_ac[0][0]',
#  omScaleLayer)                                                       'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_2[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_37 (Ba  (None, 35, 35, 32)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_33[0][0]']
#
#  batch_normalization_35 (Ba  (None, 35, 35, 32)           96        ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 35, 35, 48)           144       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  activation_34 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_31[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_34[0][0]']
#
#  batch_normalization_34 (Ba  (None, 35, 35, 32)           96        ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 35, 35, 32)           96        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 35, 35, 64)           192       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  activation_32 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  activation_35 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  block35_4_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_30[0][0]',
#  te)                                                                 'activation_32[0][0]',
#                                                                      'activation_35[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_3 (Cust  (None, 35, 35, 320)          0         ['block35_3_ac[0][0]',
#  omScaleLayer)                                                       'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_3[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_43 (Ba  (None, 35, 35, 32)           96        ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_39[0][0]']
#
#  batch_normalization_41 (Ba  (None, 35, 35, 32)           96        ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 35, 35, 48)           144       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_40 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_37[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_40[0][0]']
#
#  batch_normalization_40 (Ba  (None, 35, 35, 32)           96        ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 35, 35, 32)           96        ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_45 (Ba  (None, 35, 35, 64)           192       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_41 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  block35_5_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_36[0][0]',
#  te)                                                                 'activation_38[0][0]',
#                                                                      'activation_41[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_4 (Cust  (None, 35, 35, 320)          0         ['block35_4_ac[0][0]',
#  omScaleLayer)                                                       'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_4[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_49 (Ba  (None, 35, 35, 32)           96        ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_45[0][0]']
#
#  batch_normalization_47 (Ba  (None, 35, 35, 32)           96        ['conv2d_47[0][0]']
#  tchNormalization)
#
#  batch_normalization_50 (Ba  (None, 35, 35, 48)           144       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 35, 35, 48)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_46 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 35, 35, 32)           9216      ['activation_43[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 35, 35, 64)           27648     ['activation_46[0][0]']
#
#  batch_normalization_46 (Ba  (None, 35, 35, 32)           96        ['conv2d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 35, 35, 32)           96        ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_51 (Ba  (None, 35, 35, 64)           192       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  activation_44 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 35, 35, 64)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  block35_6_mixed (Concatena  (None, 35, 35, 128)          0         ['activation_42[0][0]',
#  te)                                                                 'activation_44[0][0]',
#                                                                      'activation_47[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 35, 35, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_5 (Cust  (None, 35, 35, 320)          0         ['block35_5_ac[0][0]',
#  omScaleLayer)                                                       'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 35, 35, 320)          0         ['custom_scale_layer_5[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_55 (Ba  (None, 35, 35, 32)           96        ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 35, 35, 32)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 35, 35, 32)           10240     ['block35_6_ac[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 35, 35, 48)           13824     ['activation_51[0][0]']
#
#  batch_normalization_53 (Ba  (None, 35, 35, 32)           96        ['conv2d_53[0][0]']
# ...
#  atchNormalization)
#
#  activation_187 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  activation_190 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  block8_7_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_187[0][0]',
#  e)                                                                  'activation_190[0][0]']
#
#  block8_7_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_7_mixed[0][0]']
#
#  custom_scale_layer_36 (Cus  (None, 8, 8, 2080)           0         ['block8_6_ac[0][0]',
#  tomScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_36[0][0]'
#                                                                     ]
#
#  conv2d_196 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  batch_normalization_196 (B  (None, 8, 8, 192)            576       ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_192 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  conv2d_197 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_192[0][0]']
#
#  batch_normalization_197 (B  (None, 8, 8, 224)            672       ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_193 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_7_ac[0][0]']
#
#  conv2d_198 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_193[0][0]']
#
#  batch_normalization_195 (B  (None, 8, 8, 192)            576       ['conv2d_195[0][0]']
#  atchNormalization)
#
#  batch_normalization_198 (B  (None, 8, 8, 256)            768       ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_191 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  activation_194 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  block8_8_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_191[0][0]',
#  e)                                                                  'activation_194[0][0]']
#
#  block8_8_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_37 (Cus  (None, 8, 8, 2080)           0         ['block8_7_ac[0][0]',
#  tomScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_37[0][0]'
#                                                                     ]
#
#  conv2d_200 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_200 (B  (None, 8, 8, 192)            576       ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_196 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_196[0][0]']
#
#  batch_normalization_201 (B  (None, 8, 8, 224)            672       ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_197 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_8_ac[0][0]']
#
#  conv2d_202 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_197[0][0]']
#
#  batch_normalization_199 (B  (None, 8, 8, 192)            576       ['conv2d_199[0][0]']
#  atchNormalization)
#
#  batch_normalization_202 (B  (None, 8, 8, 256)            768       ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_195 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  activation_198 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  block8_9_mixed (Concatenat  (None, 8, 8, 448)            0         ['activation_195[0][0]',
#  e)                                                                  'activation_198[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 8, 8, 2080)           933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_38 (Cus  (None, 8, 8, 2080)           0         ['block8_8_ac[0][0]',
#  tomScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 8, 8, 2080)           0         ['custom_scale_layer_38[0][0]'
#                                                                     ]
#
#  conv2d_204 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_204 (B  (None, 8, 8, 192)            576       ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_200 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  conv2d_205 (Conv2D)         (None, 8, 8, 224)            129024    ['activation_200[0][0]']
#
#  batch_normalization_205 (B  (None, 8, 8, 224)            672       ['conv2d_205[0][0]']
#  atchNormalization)
#
#  activation_201 (Activation  (None, 8, 8, 224)            0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  conv2d_203 (Conv2D)         (None, 8, 8, 192)            399360    ['block8_9_ac[0][0]']
#
#  conv2d_206 (Conv2D)         (None, 8, 8, 256)            172032    ['activation_201[0][0]']
#
#  batch_normalization_203 (B  (None, 8, 8, 192)            576       ['conv2d_203[0][0]']
#  atchNormalization)
#
#  batch_normalization_206 (B  (None, 8, 8, 256)            768       ['conv2d_206[0][0]']
#  atchNormalization)
#
#  activation_199 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_203[0][0
#  )                                                                  ]']
#
#  activation_202 (Activation  (None, 8, 8, 256)            0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  block8_10_mixed (Concatena  (None, 8, 8, 448)            0         ['activation_199[0][0]',
#  te)                                                                 'activation_202[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 8, 8, 2080)           933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_39 (Cus  (None, 8, 8, 2080)           0         ['block8_9_ac[0][0]',
#  tomScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 8, 8, 1536)           3194880   ['custom_scale_layer_39[0][0]'
#                                                                     ]
#
#  conv_7b_bn (BatchNormaliza  (None, 8, 8, 1536)           4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 8, 8, 1536)           0         ['conv_7b_bn[0][0]']
#
#  avg_pool (GlobalAveragePoo  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  ling2D)
#
#  predictions (Dense)         (None, 1000)                 1537000   ['avg_pool[0][0]']
#
# ==================================================================================================
# Total params: 55873736 (213.14 MB)
# Trainable params: 55813192 (212.91 MB)
# Non-trainable params: 60544 (236.50 KB)
# __________________________________________________________________________________________________

# %%
predict_image(inception_resnet_model, img_path, inception_resnet_v2.preprocess_input,
              inception_resnet_v2.decode_predictions, (299, 299))
# Out:
# 1/1 [==============================] - 9s 9s/step
#   Predicted Class             Name  Probability
# 0       n04423845          thimble     0.591926
# 1       n03759954       microphone     0.078071
# 2       n04372370           switch     0.020459
# 3       n03857828     oscilloscope     0.007069
# 4       n04153751            screw     0.004751
# 5       n03916031          perfume     0.003844
# 6       n03602883         joystick     0.003301
# 7       n03494278        harmonica     0.002623
# 8       n03532672             hook     0.002507
# 9       n03272010  electric_guitar     0.002399

# %% [markdown]
# Using NASNetLarge

# %%
from keras.applications import nasnet

nasnetlarge_model = nasnet.NASNetLarge(weights='imagenet')
nasnetlarge_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-large.h5
# 359748576/359748576 [==============================] - 2s 0us/step
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 331, 331, 3)]        0         []
#
#  stem_conv1 (Conv2D)         (None, 165, 165, 96)         2592      ['input_5[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 165, 165, 96)         384       ['stem_conv1[0][0]']
#  on)
#
#  activation_203 (Activation  (None, 165, 165, 96)         0         ['stem_bn1[0][0]']
#  )
#
#  reduction_conv_1_stem_1 (C  (None, 165, 165, 42)         4032      ['activation_203[0][0]']
#  onv2D)
#
#  reduction_bn_1_stem_1 (Bat  (None, 165, 165, 42)         168       ['reduction_conv_1_stem_1[0][0
#  chNormalization)                                                   ]']
#
#  activation_204 (Activation  (None, 165, 165, 42)         0         ['reduction_bn_1_stem_1[0][0]'
#  )                                                                  ]
#
#  activation_206 (Activation  (None, 165, 165, 96)         0         ['stem_bn1[0][0]']
#  )
#
#  separable_conv_1_pad_reduc  (None, 169, 169, 42)         0         ['activation_204[0][0]']
#  tion_left1_stem_1 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 171, 171, 96)         0         ['activation_206[0][0]']
#  tion_right1_stem_1 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 83, 83, 42)           2814      ['separable_conv_1_pad_reducti
#  _left1_stem_1 (SeparableCo                                         on_left1_stem_1[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 83, 83, 42)           8736      ['separable_conv_1_pad_reducti
#  _right1_stem_1 (SeparableC                                         on_right1_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_1_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_1_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  activation_205 (Activation  (None, 83, 83, 42)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left1_stem_1[0][0]']
#
#  activation_207 (Activation  (None, 83, 83, 42)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right1_stem_1[0][0]']
#
#  separable_conv_2_reduction  (None, 83, 83, 42)           2814      ['activation_205[0][0]']
#  _left1_stem_1 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 83, 83, 42)           3822      ['activation_207[0][0]']
#  _right1_stem_1 (SeparableC
#  onv2D)
#
#  activation_208 (Activation  (None, 165, 165, 96)         0         ['stem_bn1[0][0]']
#  )
#
#  separable_conv_2_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_2_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_2_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 171, 171, 96)         0         ['activation_208[0][0]']
#  tion_right2_stem_1 (ZeroPa
#  dding2D)
#
#  activation_210 (Activation  (None, 165, 165, 96)         0         ['stem_bn1[0][0]']
#  )
#
#  reduction_add_1_stem_1 (Ad  (None, 83, 83, 42)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_1[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_1_reduction  (None, 83, 83, 42)           8736      ['separable_conv_1_pad_reducti
#  _right2_stem_1 (SeparableC                                         on_right2_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 169, 169, 96)         0         ['activation_210[0][0]']
#  tion_right3_stem_1 (ZeroPa
#  dding2D)
#
#  activation_212 (Activation  (None, 83, 83, 42)           0         ['reduction_add_1_stem_1[0][0]
#  )                                                                  ']
#
#  separable_conv_1_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_1_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 83, 83, 42)           6432      ['separable_conv_1_pad_reducti
#  _right3_stem_1 (SeparableC                                         on_right3_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 83, 83, 42)           2142      ['activation_212[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  activation_209 (Activation  (None, 83, 83, 42)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_1_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_1_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_pad_1_stem_1 (Ze  (None, 167, 167, 42)         0         ['reduction_bn_1_stem_1[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 83, 83, 42)           3822      ['activation_209[0][0]']
#  _right2_stem_1 (SeparableC
#  onv2D)
#
#  activation_211 (Activation  (None, 83, 83, 42)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right3_stem_1[0][0]']
#
#  activation_213 (Activation  (None, 83, 83, 42)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (Ma  (None, 83, 83, 42)           0         ['reduction_pad_1_stem_1[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_2_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 83, 83, 42)           2814      ['activation_211[0][0]']
#  _right3_stem_1 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 83, 83, 42)           2142      ['activation_213[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_stem_2 (Acti  (None, 165, 165, 96)         0         ['stem_bn1[0][0]']
#  vation)
#
#  reduction_add_2_stem_1 (Ad  (None, 83, 83, 42)           0         ['reduction_left2_stem_1[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Av  (None, 83, 83, 42)           0         ['reduction_pad_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_2_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  reduction_left4_stem_1 (Av  (None, 83, 83, 42)           0         ['reduction_add_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 83, 83, 42)           168       ['separable_conv_2_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_right5_stem_1 (M  (None, 83, 83, 42)           0         ['reduction_pad_1_stem_1[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d (ZeroPaddin  (None, 166, 166, 96)         0         ['adjust_relu_1_stem_2[0][0]']
#  g2D)
#
#  reduction_add3_stem_1 (Add  (None, 83, 83, 42)           0         ['reduction_left3_stem_1[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  add_12 (Add)                (None, 83, 83, 42)           0         ['reduction_add_2_stem_1[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_1[0][0]
#                                                                     ']
#
#  reduction_add4_stem_1 (Add  (None, 83, 83, 42)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]',
#                                                                      'reduction_right5_stem_1[0][0
#                                                                     ]']
#
#  cropping2d (Cropping2D)     (None, 165, 165, 96)         0         ['zero_padding2d[0][0]']
#
#  reduction_concat_stem_1 (C  (None, 83, 83, 168)          0         ['reduction_add_2_stem_1[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_1[0][0]'
#                                                                     , 'add_12[0][0]',
#                                                                      'reduction_add4_stem_1[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_stem_2 (  (None, 83, 83, 96)           0         ['adjust_relu_1_stem_2[0][0]']
#  AveragePooling2D)
#
#  adjust_avg_pool_2_stem_2 (  (None, 83, 83, 96)           0         ['cropping2d[0][0]']
#  AveragePooling2D)
#
#  activation_214 (Activation  (None, 83, 83, 168)          0         ['reduction_concat_stem_1[0][0
#  )                                                                  ]']
#
#  adjust_conv_1_stem_2 (Conv  (None, 83, 83, 42)           4032      ['adjust_avg_pool_1_stem_2[0][
#  2D)                                                                0]']
#
#  adjust_conv_2_stem_2 (Conv  (None, 83, 83, 42)           4032      ['adjust_avg_pool_2_stem_2[0][
#  2D)                                                                0]']
#
#  reduction_conv_1_stem_2 (C  (None, 83, 83, 84)           14112     ['activation_214[0][0]']
#  onv2D)
#
#  concatenate (Concatenate)   (None, 83, 83, 84)           0         ['adjust_conv_1_stem_2[0][0]',
#                                                                      'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (Bat  (None, 83, 83, 84)           336       ['reduction_conv_1_stem_2[0][0
#  chNormalization)                                                   ]']
#
#  adjust_bn_stem_2 (BatchNor  (None, 83, 83, 84)           336       ['concatenate[0][0]']
#  malization)
#
#  activation_215 (Activation  (None, 83, 83, 84)           0         ['reduction_bn_1_stem_2[0][0]'
#  )                                                                  ]
#
#  activation_217 (Activation  (None, 83, 83, 84)           0         ['adjust_bn_stem_2[0][0]']
#  )
#
#  separable_conv_1_pad_reduc  (None, 87, 87, 84)           0         ['activation_215[0][0]']
#  tion_left1_stem_2 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 89, 89, 84)           0         ['activation_217[0][0]']
#  tion_right1_stem_2 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 42, 42, 84)           9156      ['separable_conv_1_pad_reducti
#  _left1_stem_2 (SeparableCo                                         on_left1_stem_2[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 42, 42, 84)           11172     ['separable_conv_1_pad_reducti
#  _right1_stem_2 (SeparableC                                         on_right1_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_1_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_1_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  activation_216 (Activation  (None, 42, 42, 84)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left1_stem_2[0][0]']
#
#  activation_218 (Activation  (None, 42, 42, 84)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right1_stem_2[0][0]']
#
#  separable_conv_2_reduction  (None, 42, 42, 84)           9156      ['activation_216[0][0]']
#  _left1_stem_2 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 42, 42, 84)           11172     ['activation_218[0][0]']
#  _right1_stem_2 (SeparableC
#  onv2D)
#
#  activation_219 (Activation  (None, 83, 83, 84)           0         ['adjust_bn_stem_2[0][0]']
#  )
#
#  separable_conv_2_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_2_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_2_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 89, 89, 84)           0         ['activation_219[0][0]']
#  tion_right2_stem_2 (ZeroPa
#  dding2D)
#
#  activation_221 (Activation  (None, 83, 83, 84)           0         ['adjust_bn_stem_2[0][0]']
#  )
#
#  reduction_add_1_stem_2 (Ad  (None, 42, 42, 84)           0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_2[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_1_reduction  (None, 42, 42, 84)           11172     ['separable_conv_1_pad_reducti
#  _right2_stem_2 (SeparableC                                         on_right2_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 87, 87, 84)           0         ['activation_221[0][0]']
#  tion_right3_stem_2 (ZeroPa
#  dding2D)
#
#  activation_223 (Activation  (None, 42, 42, 84)           0         ['reduction_add_1_stem_2[0][0]
#  )                                                                  ']
#
#  separable_conv_1_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_1_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 42, 42, 84)           9156      ['separable_conv_1_pad_reducti
#  _right3_stem_2 (SeparableC                                         on_right3_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 42, 42, 84)           7812      ['activation_223[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  activation_220 (Activation  (None, 42, 42, 84)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_1_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_1_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_pad_1_stem_2 (Ze  (None, 85, 85, 84)           0         ['reduction_bn_1_stem_2[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 42, 42, 84)           11172     ['activation_220[0][0]']
#  _right2_stem_2 (SeparableC
#  onv2D)
#
#  activation_222 (Activation  (None, 42, 42, 84)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_right3_stem_2[0][0]']
#
#  activation_224 (Activation  (None, 42, 42, 84)           0         ['separable_conv_1_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (Ma  (None, 42, 42, 84)           0         ['reduction_pad_1_stem_2[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_2_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 42, 42, 84)           9156      ['activation_222[0][0]']
#  _right3_stem_2 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 42, 42, 84)           7812      ['activation_224[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_0 (Activatio  (None, 83, 83, 168)          0         ['reduction_concat_stem_1[0][0
#  n)                                                                 ]']
#
#  reduction_add_2_stem_2 (Ad  (None, 42, 42, 84)           0         ['reduction_left2_stem_2[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Av  (None, 42, 42, 84)           0         ['reduction_pad_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_2_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  reduction_left4_stem_2 (Av  (None, 42, 42, 84)           0         ['reduction_add_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 42, 42, 84)           336       ['separable_conv_2_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_right5_stem_2 (M  (None, 42, 42, 84)           0         ['reduction_pad_1_stem_2[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d_1 (ZeroPadd  (None, 84, 84, 168)          0         ['adjust_relu_1_0[0][0]']
#  ing2D)
#
#  reduction_add3_stem_2 (Add  (None, 42, 42, 84)           0         ['reduction_left3_stem_2[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  add_13 (Add)                (None, 42, 42, 84)           0         ['reduction_add_2_stem_2[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_2[0][0]
#                                                                     ']
#
#  reduction_add4_stem_2 (Add  (None, 42, 42, 84)           0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]',
#                                                                      'reduction_right5_stem_2[0][0
#                                                                     ]']
#
#  cropping2d_1 (Cropping2D)   (None, 83, 83, 168)          0         ['zero_padding2d_1[0][0]']
#
#  reduction_concat_stem_2 (C  (None, 42, 42, 336)          0         ['reduction_add_2_stem_2[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_2[0][0]'
#                                                                     , 'add_13[0][0]',
#                                                                      'reduction_add4_stem_2[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_0 (Avera  (None, 42, 42, 168)          0         ['adjust_relu_1_0[0][0]']
#  gePooling2D)
#
#  adjust_avg_pool_2_0 (Avera  (None, 42, 42, 168)          0         ['cropping2d_1[0][0]']
#  gePooling2D)
#
#  adjust_conv_1_0 (Conv2D)    (None, 42, 42, 84)           14112     ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)    (None, 42, 42, 84)           14112     ['adjust_avg_pool_2_0[0][0]']
#
#  activation_225 (Activation  (None, 42, 42, 336)          0         ['reduction_concat_stem_2[0][0
#  )                                                                  ]']
#
#  concatenate_1 (Concatenate  (None, 42, 42, 168)          0         ['adjust_conv_1_0[0][0]',
#  )                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)    (None, 42, 42, 168)          56448     ['activation_225[0][0]']
#
#  adjust_bn_0 (BatchNormaliz  (None, 42, 42, 168)          672       ['concatenate_1[0][0]']
#  ation)
#
#  normal_bn_1_0 (BatchNormal  (None, 42, 42, 168)          672       ['normal_conv_1_0[0][0]']
#  ization)
#
#  activation_226 (Activation  (None, 42, 42, 168)          0         ['normal_bn_1_0[0][0]']
#  )
#
#  activation_228 (Activation  (None, 42, 42, 168)          0         ['adjust_bn_0[0][0]']
#  )
#
#  activation_230 (Activation  (None, 42, 42, 168)          0         ['adjust_bn_0[0][0]']
#  )
#
#  activation_232 (Activation  (None, 42, 42, 168)          0         ['adjust_bn_0[0][0]']
#  )
#
#  activation_234 (Activation  (None, 42, 42, 168)          0         ['normal_bn_1_0[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 42, 42, 168)          32424     ['activation_226[0][0]']
#  ft1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 42, 42, 168)          29736     ['activation_228[0][0]']
#  ght1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 42, 42, 168)          32424     ['activation_230[0][0]']
#  ft2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 42, 42, 168)          29736     ['activation_232[0][0]']
#  ght2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 42, 42, 168)          29736     ['activation_234[0][0]']
#  ft5_0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 42, 42, 168)          672       ['separable_conv_1_normal_left
#  _left1_0 (BatchNormalizati                                         1_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 42, 42, 168)          672       ['separable_conv_1_normal_righ
#  _right1_0 (BatchNormalizat                                         t1_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 42, 42, 168)          672       ['separable_conv_1_normal_left
#  _left2_0 (BatchNormalizati                                         2_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 42, 42, 168)          672       ['separable_conv_1_normal_righ
#  _right2_0 (BatchNormalizat                                         t2_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 42, 42, 168)          672       ['separable_conv_1_normal_left
#  _left5_0 (BatchNormalizati                                         5_0[0][0]']
#  on)
#
# ...
#  )
#
#  adjust_conv_projection_18   (None, 11, 11, 672)          2709504   ['activation_450[0][0]']
#  (Conv2D)
#
#  normal_conv_1_18 (Conv2D)   (None, 11, 11, 672)          2709504   ['activation_451[0][0]']
#
#  adjust_bn_18 (BatchNormali  (None, 11, 11, 672)          2688      ['adjust_conv_projection_18[0]
#  zation)                                                            [0]']
#
#  normal_bn_1_18 (BatchNorma  (None, 11, 11, 672)          2688      ['normal_conv_1_18[0][0]']
#  lization)
#
#  activation_452 (Activation  (None, 11, 11, 672)          0         ['normal_bn_1_18[0][0]']
#  )
#
#  activation_454 (Activation  (None, 11, 11, 672)          0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_456 (Activation  (None, 11, 11, 672)          0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_458 (Activation  (None, 11, 11, 672)          0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_460 (Activation  (None, 11, 11, 672)          0         ['normal_bn_1_18[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 11, 11, 672)          468384    ['activation_452[0][0]']
#  ft1_18 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 11, 11, 672)          457632    ['activation_454[0][0]']
#  ght1_18 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 11, 11, 672)          468384    ['activation_456[0][0]']
#  ft2_18 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 11, 11, 672)          457632    ['activation_458[0][0]']
#  ght2_18 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 11, 11, 672)          457632    ['activation_460[0][0]']
#  ft5_18 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_1_normal_left
#  _left1_18 (BatchNormalizat                                         1_18[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_1_normal_righ
#  _right1_18 (BatchNormaliza                                         t1_18[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_1_normal_left
#  _left2_18 (BatchNormalizat                                         2_18[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_1_normal_righ
#  _right2_18 (BatchNormaliza                                         t2_18[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_1_normal_left
#  _left5_18 (BatchNormalizat                                         5_18[0][0]']
#  ion)
#
#  activation_453 (Activation  (None, 11, 11, 672)          0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft1_18[0][0]']
#
#  activation_455 (Activation  (None, 11, 11, 672)          0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight1_18[0][0]']
#
#  activation_457 (Activation  (None, 11, 11, 672)          0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft2_18[0][0]']
#
#  activation_459 (Activation  (None, 11, 11, 672)          0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight2_18[0][0]']
#
#  activation_461 (Activation  (None, 11, 11, 672)          0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft5_18[0][0]']
#
#  separable_conv_2_normal_le  (None, 11, 11, 672)          468384    ['activation_453[0][0]']
#  ft1_18 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 11, 11, 672)          457632    ['activation_455[0][0]']
#  ght1_18 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 11, 11, 672)          468384    ['activation_457[0][0]']
#  ft2_18 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 11, 11, 672)          457632    ['activation_459[0][0]']
#  ght2_18 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 11, 11, 672)          457632    ['activation_461[0][0]']
#  ft5_18 (SeparableConv2D)
#
#  separable_conv_2_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_2_normal_left
#  _left1_18 (BatchNormalizat                                         1_18[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_2_normal_righ
#  _right1_18 (BatchNormaliza                                         t1_18[0][0]']
#  tion)
#
#  separable_conv_2_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_2_normal_left
#  _left2_18 (BatchNormalizat                                         2_18[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_2_normal_righ
#  _right2_18 (BatchNormaliza                                         t2_18[0][0]']
#  tion)
#
#  normal_left3_18 (AveragePo  (None, 11, 11, 672)          0         ['normal_bn_1_18[0][0]']
#  oling2D)
#
#  normal_left4_18 (AveragePo  (None, 11, 11, 672)          0         ['adjust_bn_18[0][0]']
#  oling2D)
#
#  normal_right4_18 (AverageP  (None, 11, 11, 672)          0         ['adjust_bn_18[0][0]']
#  ooling2D)
#
#  separable_conv_2_bn_normal  (None, 11, 11, 672)          2688      ['separable_conv_2_normal_left
#  _left5_18 (BatchNormalizat                                         5_18[0][0]']
#  ion)
#
#  normal_add_1_18 (Add)       (None, 11, 11, 672)          0         ['separable_conv_2_bn_normal_l
#                                                                     eft1_18[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight1_18[0][0]']
#
#  normal_add_2_18 (Add)       (None, 11, 11, 672)          0         ['separable_conv_2_bn_normal_l
#                                                                     eft2_18[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight2_18[0][0]']
#
#  normal_add_3_18 (Add)       (None, 11, 11, 672)          0         ['normal_left3_18[0][0]',
#                                                                      'adjust_bn_18[0][0]']
#
#  normal_add_4_18 (Add)       (None, 11, 11, 672)          0         ['normal_left4_18[0][0]',
#                                                                      'normal_right4_18[0][0]']
#
#  normal_add_5_18 (Add)       (None, 11, 11, 672)          0         ['separable_conv_2_bn_normal_l
#                                                                     eft5_18[0][0]',
#                                                                      'normal_bn_1_18[0][0]']
#
#  normal_concat_18 (Concaten  (None, 11, 11, 4032)         0         ['adjust_bn_18[0][0]',
#  ate)                                                                'normal_add_1_18[0][0]',
#                                                                      'normal_add_2_18[0][0]',
#                                                                      'normal_add_3_18[0][0]',
#                                                                      'normal_add_4_18[0][0]',
#                                                                      'normal_add_5_18[0][0]']
#
#  activation_462 (Activation  (None, 11, 11, 4032)         0         ['normal_concat_18[0][0]']
#  )
#
#  global_average_pooling2d (  (None, 4032)                 0         ['activation_462[0][0]']
#  GlobalAveragePooling2D)
#
#  predictions (Dense)         (None, 1000)                 4033000   ['global_average_pooling2d[0][
#                                                                     0]']
#
# ==================================================================================================
# Total params: 88949818 (339.32 MB)
# Trainable params: 88753150 (338.57 MB)
# Non-trainable params: 196668 (768.23 KB)
# __________________________________________________________________________________________________

# %%
predict_image(nasnetlarge_model, img_path, nasnet.preprocess_input, nasnet.decode_predictions, (331, 331))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x795350e66200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 14s 14s/step
#   Predicted Class              Name  Probability
# 0       n03759954        microphone     0.702069
# 1       n04423845           thimble     0.138759
# 2       n04041544             radio     0.003071
# 3       n04372370            switch     0.002737
# 4       n04074963    remote_control     0.001960
# 5       n03075370  combination_lock     0.001902
# 6       n03666591           lighter     0.001818
# 7       n04296562             stage     0.001629
# 8       n03255030          dumbbell     0.001524
# 9       n03272010   electric_guitar     0.001513

# %% [markdown]
# > Xception seems to have confidently identified the microphone, while NASNetLarge have shown some uncertainty, and InceptionResNetV2 got the class evidently wrong, possibly due to the presence of features resembling a thimble, just like what happened to VGG16. It's important to note that models have different architectures, which means they learn different features and patterns from the input data. They were also trained on different datasets with varying images and labels, leading to variations in their learned representations.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# > In summary, I explored 5 different pre-trained deep learning models to predict the class of an image. ResNet50, Xception, and NASNetLarge consistently identified the microphone accurately. However, NASNetLarge had a lower confidence in its prediction, and InceptionResNetV2 and VGG16 faced challenges, making unexpected primary predictions. These models are certainly not perfect and may sometimes make errors, especially when faced with challenging or ambiguous inputs. Additionally, the functions to capture and save a webcam capture could not run properly, therefore I opted to use the code snippet for camera capture built in to Google Colab.
